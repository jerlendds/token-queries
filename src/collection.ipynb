# %% [markdown]
# # Pydantic models for SERPs (search engine result pages)

# %%
from enum import Enum
from pydantic import BaseModel

class SearchSourceEnum(str, Enum):
    google = 'google'
    ddg = 'duckduckgo'
    bing = 'bing'
    yandex = 'yandex'
    brave = 'brave'
    yahoo = 'yahoo'
    ecosia = 'firecracker'
    qwant = 'qwant'
    aol = 'aol'

class SerpInput(BaseModel):
    pass

class SerpOutput(BaseModel):
    title: str
    description: str
    breadcrumbs: str
    display_url: str
    url: str
    source: SearchSourceEnum

# %% [markdown]
# # Collecting search queries datasets from [trends.google.com](https://trends.google.com) and various sources
#
# This is a simple `aiohttp` crawler for adding additions to our search queries dataset

# %%
# cookies = {
#     'NID': '525=bZa35AR_9LHsoGvCWVhAAmzTKb81Q1j3Ug5tbJc0Oh2ZQVrjNkG-jubxLdAxFtp0uzNySdmH9FCZ55rwZvxh1NWch9k6PsVb9fIfMreO6C8SmRg2xbIVphfq6QaHWTPZM-zmUQKqkmmGot46NbI0LwzZiPjKWZD1gCwpB3DdWvCoKxvewFwEBvO5rS76P5SmUzQ0n2BdFbH8yOPvuzl8_TLKF1MtU_6OZYUB6ryrE0zmSN29N3OOugZFB4KxH0Yk_b4McCVDogBfA0VFwU4W2luKuStNNnoGsJfaAFd8HjXMfEatRFb-VwCNtUqMeK5JeoGxmnyPorMG9e3FlDtjzTtdVGkXHvffCKKwX72SN9N5TMeQk5rQ15iDByjeotQaPWuaqpjJ6EWBJVPID_xlmtq63hnw2PaDcQXqy_kzpyyyq7mTbH3wofCE',
#     'SEARCH_SAMESITE': 'CgQIv54B',
#     'AEC': 'AVh_V2h6p3VYs1jmgqY_RX-XMSenyDQ4lsJdcHZ3Oyp1Q90yh5s3BbwTqg',
#     'OTZ': '8237762_80_84_104220_80_446880',
# }

google_trends_headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:142.0) Gecko/20100101 Firefox/142.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate, br, zstd',
    'Connection': 'keep-alive',
    'Referer': 'https://trends.google.com/trends/explore?geo=CA&q=OSINT&hl=en-US',
    'Cookie': 'NID=525=bZa35AR_9LHsoGvCWVhAAmzTKb81Q1j3Ug5tbJc0Oh2ZQVrjNkG-jubxLdAxFtp0uzNySdmH9FCZ55rwZvxh1NWch9k6PsVb9fIfMreO6C8SmRg2xbIVphfq6QaHWTPZM-zmUQKqkmmGot46NbI0LwzZiPjKWZD1gCwpB3DdWvCoKxvewFwEBvO5rS76P5SmUzQ0n2BdFbH8yOPvuzl8_TLKF1MtU_6OZYUB6ryrE0zmSN29N3OOugZFB4KxH0Yk_b4McCVDogBfA0VFwU4W2luKuStNNnoGsJfaAFd8HjXMfEatRFb-VwCNtUqMeK5JeoGxmnyPorMG9e3FlDtjzTtdVGkXHvffCKKwX72SN9N5TMeQk5rQ15iDByjeotQaPWuaqpjJ6EWBJVPID_xlmtq63hnw2PaDcQXqy_kzpyyyq7mTbH3wofCE; SEARCH_SAMESITE=CgQIv54B; AEC=AVh_V2h6p3VYs1jmgqY_RX-XMSenyDQ4lsJdcHZ3Oyp1Q90yh5s3BbwTqg; OTZ=8237762_80_84_104220_80_446880',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Host': 'trends.google.com',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'TE': 'trailers',
}

# %%
import aiohttp
import json
import urllib.parse
import asyncio

TRENDS_TOKEN = "APP6_UEAAAAAaLSGzuAxitMWsZXYwz3dmMHa7M_gVOAw"

async def main(COUNTRY_CODE, QUERY):
    trends_req = json.dumps({"restriction":{"geo": {"country": COUNTRY_CODE},"time":"2024-08-30 2025-08-30","originalTimeRangeForExploreUrl":"today 12-m","complexKeywordsRestriction":{"keyword":[{"type":"BROAD","value": QUERY}]}},"keywordType":"QUERY","metric":["TOP","RISING"],"trendinessSettings":{"compareTime":"2023-08-30 2024-08-29"},"requestOptions":{"property":"","backend":"IZG","category":0},"language":"en","userCountryCode": COUNTRY_CODE,"userConfig":{"userType":"USER_TYPE_LEGIT_USER"}})
    req = urllib.parse.quote_plus(trends_req)
    # Google doesn't urlencode `:` or `,` so we need to fix
    # the Python url encoding to work with google with these replaces
    req = req.replace("%3A", ":").replace("%2C", ",")
    google_trends_url = f'https://trends.google.com/trends/api/widgetdata/relatedsearches?hl=en-US&tz=360&req={req}&token={TRENDS_TOKEN}'
    print(f"Pulling Google Trends related queries\nCountry: {COUNTRY_CODE}\nQuery: {QUERY}")
    print(f"Google Trends Request URL: {google_trends_url}")
    print("---")
    async with aiohttp.ClientSession(headers=google_trends_headers) as session:
        async with session.get(google_trends_url) as response:

            print("Status:", response.status)
            print("Content-type:", response.headers['content-type'])

            json_str = await response.text()
            json_str = json_str.replace(")]}',", "")
            json_response = json.loads(json_str)
            
            # Pretty print related queries response:
            print("Response: ", json.dumps(json_response, indent=4))

await main("CA", "OSINT")
# Out:
# Pulling Google Trends related queries
# Country: CA
# Query: OSINT
# Google Trends Request URL: https://trends.google.com/trends/api/widgetdata/relatedsearches?hl=en-US&tz=360&req=%7B%22restriction%22:+%7B%22geo%22:+%7B%22country%22:+%22CA%22%7D,+%22time%22:+%222024-08-30+2025-08-30%22,+%22originalTimeRangeForExploreUrl%22:+%22today+12-m%22,+%22complexKeywordsRestriction%22:+%7B%22keyword%22:+%5B%7B%22type%22:+%22BROAD%22,+%22value%22:+%22OSINT%22%7D%5D%7D%7D,+%22keywordType%22:+%22QUERY%22,+%22metric%22:+%5B%22TOP%22,+%22RISING%22%5D,+%22trendinessSettings%22:+%7B%22compareTime%22:+%222023-08-30+2024-08-29%22%7D,+%22requestOptions%22:+%7B%22property%22:+%22%22,+%22backend%22:+%22IZG%22,+%22category%22:+0%7D,+%22language%22:+%22en%22,+%22userCountryCode%22:+%22CA%22,+%22userConfig%22:+%7B%22userType%22:+%22USER_TYPE_LEGIT_USER%22%7D%7D&token=APP6_UEAAAAAaLSGzuAxitMWsZXYwz3dmMHa7M_gVOAw
# ---
# Status: 200
# Content-type: application/json; charset=UTF-8
# Response:  {
#     "default": {
#         "rankedList": [
#             {
#                 "rankedKeyword": [
#                     {
#                         "query": "osint twitter",
#                         "value": 100,
#                         "formattedValue": "100",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint defender",
#                         "value": 78,
#                         "formattedValue": "78",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+defender&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "twitter osint defender",
#                         "value": 56,
#                         "formattedValue": "56",
#                         "hasData": true,
#                         "link": "/trends/explore?q=twitter+osint+defender&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint technical",
#                         "value": 51,
#                         "formattedValue": "51",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+technical&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "twitter osint technical",
#                         "value": 46,
#                         "formattedValue": "46",
#                         "hasData": true,
#                         "link": "/trends/explore?q=twitter+osint+technical&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint framework",
#                         "value": 30,
#                         "formattedValue": "30",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+framework&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint tools",
#                         "value": 29,
#                         "formattedValue": "29",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+tools&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "reddit osint",
#                         "value": 28,
#                         "formattedValue": "28",
#                         "hasData": true,
#                         "link": "/trends/explore?q=reddit+osint&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "what is osint",
#                         "value": 23,
#                         "formattedValue": "23",
#                         "hasData": true,
#                         "link": "/trends/explore?q=what+is+osint&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "email osint",
#                         "value": 20,
#                         "formattedValue": "20",
#                         "hasData": true,
#                         "link": "/trends/explore?q=email+osint&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint industries",
#                         "value": 19,
#                         "formattedValue": "19",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+industries&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint tool",
#                         "value": 17,
#                         "formattedValue": "17",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+tool&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint meaning",
#                         "value": 15,
#                         "formattedValue": "15",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+meaning&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "tendar",
#                         "value": 15,
#                         "formattedValue": "15",
#                         "hasData": true,
#                         "link": "/trends/explore?q=tendar&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "tendar twitter",
#                         "value": 14,
#                         "formattedValue": "14",
#                         "hasData": true,
#                         "link": "/trends/explore?q=tendar+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint jobs",
#                         "value": 13,
#                         "formattedValue": "13",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+jobs&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint training",
#                         "value": 13,
#                         "formattedValue": "13",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+training&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint github",
#                         "value": 11,
#                         "formattedValue": "11",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+github&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "wartranslated twitter",
#                         "value": 11,
#                         "formattedValue": "11",
#                         "hasData": true,
#                         "link": "/trends/explore?q=wartranslated+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint defender x",
#                         "value": 11,
#                         "formattedValue": "11",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+defender+x&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint course",
#                         "value": 10,
#                         "formattedValue": "10",
#                         "hasData": true,
#                         "link": "/trends/explore?q=osint+course&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "ukraine",
#                         "value": 9,
#                         "formattedValue": "9",
#                         "hasData": true,
#                         "link": "/trends/explore?q=ukraine&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "nexta twitter",
#                         "value": 8,
#                         "formattedValue": "8",
#                         "hasData": true,
#                         "link": "/trends/explore?q=nexta+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "rob lee twitter",
#                         "value": 8,
#                         "formattedValue": "8",
#                         "hasData": true,
#                         "link": "/trends/explore?q=rob+lee+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "sherlock osint",
#                         "value": 8,
#                         "formattedValue": "8",
#                         "hasData": true,
#                         "link": "/trends/explore?q=sherlock+osint&date=today+12-m&geo=CA"
#                     }
#                 ]
#             },
#             {
#                 "rankedKeyword": [
#                     {
#                         "query": "sherlock osint",
#                         "value": 126700,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=sherlock+osint&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "idcrawl",
#                         "value": 37850,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=idcrawl&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "maks24 twitter",
#                         "value": 34100,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=maks24+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "megh updates",
#                         "value": 23050,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=megh+updates&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint613",
#                         "value": 19850,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=osint613&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "middle east observer",
#                         "value": 16600,
#                         "formattedValue": "Breakout",
#                         "link": "/trends/explore?q=middle+east+observer&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint uri twitter",
#                         "value": 250,
#                         "formattedValue": "+250%",
#                         "link": "/trends/explore?q=osint+uri+twitter&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint uri",
#                         "value": 180,
#                         "formattedValue": "+180%",
#                         "link": "/trends/explore?q=osint+uri&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint training",
#                         "value": 60,
#                         "formattedValue": "+60%",
#                         "link": "/trends/explore?q=osint+training&date=today+12-m&geo=CA"
#                     },
#                     {
#                         "query": "osint tool",
#                         "value": 50,
#                         "formattedValue": "+50%",
#                         "link": "/trends/explore?q=osint+tool&date=today+12-m&geo=CA"
#                     }
#                 ]
#             }
#         ]
#     }
# }
